# %%
import pandas as pd

# %%
df_calls = pd.read_csv('../MNPD_Calls/Metro_Nashville_Police_Department_Calls_for_Service.csv', low_memory=False)
df_calls
# Out:
#            Event Number           Call Received  Complaint Number  Tencode  \
# 0        PD201400831493  08/11/2014 12:27:41 AM               NaN       93
# 1        PD201400733929  07/13/2014 09:06:57 AM      2.014066e+10       50
# 2        PD201400403153  04/17/2014 04:03:00 PM      2.014037e+10       57
# 3        PD201400035391  01/09/2014 11:10:00 PM      2.014003e+10       50
# 4        PD201401100405  10/24/2014 12:58:19 PM      2.014098e+10       50
# ...                 ...                     ...               ...      ...
# 7365087  PD202100501662  08/06/2021 08:31:12 PM               NaN       95
# 7365088  PD202100340556  05/26/2021 07:56:57 AM               NaN       15
# 7365089  PD202100370448  06/08/2021 02:18:06 PM      2.021031e+10       50
# 7365090  PD202100266286  04/24/2021 12:02:07 AM      2.021023e+10       45
# 7365091  PD202100433235  07/06/2021 06:08:19 AM               NaN     8000
#
#                         Tencode Description Tencode Suffix  \
# ...

# %%
df_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7365092 entries, 0 to 7365091
# Data columns (total 19 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Event Number                object
#  1   Call Received               object
#  2   Complaint Number            float64
#  3   Tencode                     int64
#  4   Tencode Description         object
#  5   Tencode Suffix              object
#  6   Tencode Suffix Description  object
#  7   Disposition Code            object
#  8   Disposition Description     object
#  9   Block                       float64
#  10  Street Name                 object
#  11  Unit Dispatched             object
#  12  Shift                       object
#  13  Sector                      object
#  14  Zone                        object
#  15  RPA                         float64
#  16  Latitude                    float64
#  17  Longitude                   float64
# ...

# %%
df_calls.isnull().sum()
# Out:
# Event Number                        0
# Call Received                       0
# Complaint Number              6774350
# Tencode                             0
# Tencode Description            167608
# Tencode Suffix                3135394
# Tencode Suffix Description    3696550
# Disposition Code                34954
# Disposition Description       1757290
# Block                         5485613
# Street Name                   4841421
# Unit Dispatched                465554
# Shift                               0
# Sector                        1493099
# Zone                           845601
# RPA                           1439844
# Latitude                      6172346
# Longitude                     6172346
# Mapped Location               6172346
# dtype: int64

# %%
df_calls['Event Number'].is_unique
# Out:
# False

# %%
df_calls['Event Number'].value_counts()
# Out:
# PD201400978620    7
# PD201401134789    7
# PD201401105385    6
# PD201401288910    6
# PD201400978623    6
#                  ..
# PD202000232454    1
# PD201700709264    1
# PD201700937400    1
# PD202000909717    1
# PD201800174704    1
# Name: Event Number, Length: 7362103, dtype: int64

# %%
df_calls[df_calls['Event Number'] == 'PD201401105385']
# Out:
#            Event Number           Call Received  Complaint Number  Tencode  \
# 1399893  PD201401105385  10/25/2014 09:29:54 PM               NaN       43
# 1402068  PD201401105385  10/25/2014 09:29:54 PM               NaN       43
# 1406890  PD201401105385  10/25/2014 09:29:54 PM               NaN       43
# 1410927  PD201401105385  10/25/2014 09:29:54 PM               NaN       43
# 1414768  PD201401105385  10/25/2014 09:29:54 PM               NaN       43
# 1419536  PD201401105385  10/25/2014 09:29:54 PM               NaN       43
#
#                               Tencode Description Tencode Suffix  \
# 1399893  WANT OFFICER FOR INVESTIGATION / ASSISTA              P
# 1402068  WANT OFFICER FOR INVESTIGATION / ASSISTA              P
# 1406890  WANT OFFICER FOR INVESTIGATION / ASSISTA              P
# 1410927  WANT OFFICER FOR INVESTIGATION / ASSISTA              P
# 1414768  WANT OFFICER FOR INVESTIGATION / ASSISTA              P
# ...

# %%
df_calls['Call Received'].value_counts()
# Out:
# 10/01/2020 06:26:06 PM    25
# 03/01/2018 10:52:13 AM    25
# 08/05/2019 10:17:32 AM    24
# 01/03/2019 09:58:02 AM    24
# 06/12/2018 06:31:27 PM    24
#                           ..
# 12/06/2019 06:23:01 AM     1
# 10/05/2015 02:02:05 PM     1
# 09/08/2014 03:18:43 PM     1
# 10/23/2015 12:01:18 PM     1
# 05/27/2017 12:41:18 AM     1
# Name: Call Received, Length: 7228925, dtype: int64

# %%
df_calls[df_calls['Call Received'] == '08/05/2019 10:17:32 AM']
# Out:
#            Event Number           Call Received  Complaint Number  Tencode  \
# 4262202  PD201900677119  08/05/2019 10:17:32 AM               NaN       43
# 4262471  PD201900677128  08/05/2019 10:17:32 AM               NaN       43
# 4264532  PD201900677125  08/05/2019 10:17:32 AM               NaN       43
# 4264757  PD201900677122  08/05/2019 10:17:32 AM               NaN       43
# 4266462  PD201900677132  08/05/2019 10:17:32 AM               NaN       43
# 4267709  PD201900677133  08/05/2019 10:17:32 AM               NaN       43
# 4269091  PD201900677140  08/05/2019 10:17:32 AM               NaN       43
# 4269458  PD201900677139  08/05/2019 10:17:32 AM               NaN       43
# 4269995  PD201900677129  08/05/2019 10:17:32 AM               NaN       43
# 4270675  PD201900677138  08/05/2019 10:17:32 AM               NaN       43
# 4272626  PD201900677121  08/05/2019 10:17:32 AM               NaN       43
# ...

# %%
df_mapped = df_calls[~df_calls['Latitude'].isnull()]
df_mapped
# Out:
#            Event Number           Call Received  Complaint Number  Tencode  \
# 1334     PD201400929894  09/07/2014 07:15:46 PM               NaN        3
# 1692     PD201800231514  03/04/2018 09:24:47 PM               NaN       93
# 2460     PD201900702994  08/13/2019 01:52:06 PM               NaN       93
# 2488     PD201500290544  03/19/2015 04:50:16 AM               NaN       93
# 2491     PD201500224343  03/01/2015 08:59:26 AM               NaN       96
# ...                 ...                     ...               ...      ...
# 7345540  PD202100262831  04/22/2021 03:45:05 PM      2.021023e+10       57
# 7353023  PD202100283691  05/01/2021 04:09:46 PM               NaN       43
# 7354147  PD202100492664  08/02/2021 05:41:24 PM               NaN       45
# 7356637  PD202100283693  05/01/2021 04:10:12 PM               NaN       43
# 7357487  PD202100465614  07/21/2021 10:42:20 AM               NaN       50
#
#                               Tencode Description Tencode Suffix  \
# ...
